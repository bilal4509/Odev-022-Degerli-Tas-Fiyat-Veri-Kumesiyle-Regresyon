# %% [markdown]
# <img src='111.jpg'>

# %%
#pip install pycaret

# %%
import pandas as pd

# %%
#Regression AutoMl

# %%
from pycaret.regression import*

# %%
df= pd.read_csv('train.csv')
df
# Out:
#           id  carat        cut color clarity  depth  table     x     y     z  \
# 0          0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55
# 1          1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05
# 2          2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50
# 3          3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71
# 4          4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77
# ...      ...    ...        ...   ...     ...    ...    ...   ...   ...   ...
# 58873  58873   0.74  Very Good     G     VS2   60.0   60.0  5.85  5.90  3.52
# 58874  58874   0.90  Very Good     J     SI1   61.3   63.0  6.15  6.29  3.80
# 58875  58875   1.21      Ideal     D     SI1   61.6   57.0  6.85  6.79  4.21
# 58876  58876   0.33    Premium     E     VS1   61.3   58.0  4.41  4.43  2.71
# 58877  58877    NaN        NaN   NaN     NaN    NaN    NaN   NaN   NaN   NaN
#
#          price
# 0      13619.0
# ...

# %%
df.isnull().sum()
# Out:
# id         0
# carat      1
# cut        1
# color      1
# clarity    1
# depth      1
# table      1
# x          1
# y          1
# z          1
# price      1
# dtype: int64

# %%
df.fillna(df.mean(),inplace=True)

#Boş olan değerlerin hepsini ortalama ile doldurduk

# %%
df.isnull().sum()
# Out:
# id         0
# carat      0
# cut        1
# color      1
# clarity    1
# depth      0
# table      0
# x          0
# y          0
# z          0
# price      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58878 entries, 0 to 58877
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       58878 non-null  int64
#  1   carat    58878 non-null  float64
#  2   cut      58877 non-null  object
#  3   color    58877 non-null  object
#  4   clarity  58877 non-null  object
#  5   depth    58878 non-null  float64
#  6   table    58878 non-null  float64
#  7   x        58878 non-null  float64
#  8   y        58878 non-null  float64
#  9   z        58878 non-null  float64
#  10  price    58878 non-null  float64
# dtypes: float64(7), int64(1), object(3)
# memory usage: 4.9+ MB

# %%
setup(data=df,target='price')
# Out:
# <style type="text/css">
# #T_82c53_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_82c53" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_82c53_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_82c53_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_82c53_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_82c53_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_82c53_row0_col1" class="data row0 col1" >6036</td>
#     </tr>
#     <tr>
#       <th id="T_82c53_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_82c53_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_82c53_row1_col1" class="data row1 col1" >price</td>
#     </tr>
#     <tr>
#       <th id="T_82c53_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model=compare_models()
# Out:
# <style type="text/css">
# #T_f48b9 th {
#   text-align: left;
# }
# ...

# %%
# AUTO ML İLE Light Gradient Boosting Machine modeline göre doğru tahmin oranı %97,7
